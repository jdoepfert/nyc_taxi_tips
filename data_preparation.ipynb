# %%
import urllib
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

 # for subsampling the data
from random import sample

# for plotting on a geographic map
import folium 
from folium import plugins 
import mplleaflet

# %% [markdown]
# # Getting and inspecting the data

# %% [markdown]
# Downloading the data. At the moment, only data from June 2015 is considered.

# %%
# list containing the link(s) to the csv file(s)
data_links = ['https://storage.googleapis.com/tlc-trip-data/2015/yellow_tripdata_2015-06.csv']

filenames = []
for link in data_links:
    filenames.append(link.split('/')[-1])
    if not(os.path.isfile(filenames[-1])): # do not download file if it already exists
        urllib.urlretrieve(link, filename)

# %% [markdown]
# Loading the data into a pandas data frame and look at it:

# %%
df = pd.DataFrame()
for filename in filenames:
    df = df.append(pd.read_csv(filename), ignore_index=True)

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-06-02 11:19:29   2015-06-02 11:47:52                1
# 1         2  2015-06-02 11:19:30   2015-06-02 11:27:56                1
# 2         2  2015-06-02 11:19:31   2015-06-02 11:30:30                1
# 3         2  2015-06-02 11:19:31   2015-06-02 11:39:02                1
# 4         1  2015-06-02 11:19:32   2015-06-02 11:32:49                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.63        -73.954430        40.764141           1
# 1           0.46        -73.971443        40.758942           1
# 2           0.87        -73.978111        40.738434           1
# 3           2.13        -73.945892        40.773529           1
# 4           1.40        -73.979088        40.776772           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12324935 entries, 0 to 12324934
# Data columns (total 19 columns):
# VendorID                 int64
# tpep_pickup_datetime     object
# tpep_dropoff_datetime    object
# passenger_count          int64
# trip_distance            float64
# pickup_longitude         float64
# pickup_latitude          float64
# RateCodeID               int64
# store_and_fwd_flag       object
# dropoff_longitude        float64
# dropoff_latitude         float64
# payment_type             int64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# dtypes: float64(12), int64(4), object(3)
# memory usage: 1.8+ GB

# %%
df.describe()
# Out:
#               VendorID  passenger_count    trip_distance  pickup_longitude  \
# count  12324935.000000  12324935.000000  12324935.000000   12324935.000000
# mean          1.523565         1.681898        11.829076        -72.913847
# std           0.499444         1.335180      7678.550287          8.796762
# min           1.000000         0.000000         0.000000       -759.233337
# 25%           1.000000         1.000000         1.010000        -73.991898
# 50%           2.000000         1.000000         1.750000        -73.981537
# 75%           2.000000         2.000000         3.230000        -73.966461
# max           2.000000         9.000000  10083318.000000        149.028534
#
#        pickup_latitude       RateCodeID  dropoff_longitude  dropoff_latitude  \
# count  12324935.000000  12324935.000000    12324935.000000   12324935.000000
# mean         40.166867         1.041832         -72.944737         40.184784
# ...

# %% [markdown]
# Note that some of the numerical features like tip amount and fare amount actually contain negative values. Those invalid values will be deleted in the next section.

# %% [markdown]
# # Data cleaning

# %% [markdown]
# ### 1) Retaining only trips paid by credit card
# Only the credit card tips are recorded in the data set. Therefore, let's only retain trips with credit card payment. This might introduce some bias (as credit card payers may have a different tipping behaviour than others).
#
# As seen below, most of the trips are anyway paid by credit card (label "1", followed by cash payment, label "2").

# %%
df.groupby('payment_type').size().plot(kind='bar');

# %% [markdown]
# For some trips, people actually tipped with credit card, even though they did not pay with credit card:

# %%
np.sum((df.payment_type != 1) & (df.tip_amount != 0))
# Out:
# 388

# %% [markdown]
# However, the number of those trips is negligible, so I ignore them here and only retain credit card trips. Then, the column "payment_type" can be removed:

# %%
df = df[df.payment_type == 1]
df.drop('payment_type', axis=1, inplace=True)
df.shape
# Out:
# (7719300, 18)

# %% [markdown]
# ### 2) Checking for unfeasible values in numerical features
# As seen above, some of the numerical features contained negative values. Let's have a closer look...

# %%
(df < 0).sum()
# Out:
# VendorID                       0
# tpep_pickup_datetime           0
# tpep_dropoff_datetime          0
# passenger_count                0
# trip_distance                  0
# pickup_longitude         7610164
# pickup_latitude                2
# RateCodeID                     0
# store_and_fwd_flag             0
# dropoff_longitude        7623507
# dropoff_latitude               1
# fare_amount                   10
# extra                          4
# mta_tax                        6
# tip_amount                     8
# tolls_amount                   0
# improvement_surcharge         10
# total_amount                  11
# dtype: int64

# %% [markdown]
# ...and remove the corresponding rows where negative values do not make any sense:

# %%
col_names = ['total_amount', 'improvement_surcharge', 'tip_amount', 'mta_tax', 'extra', 'fare_amount']

# this removes all rows where at least one value of the columns in col_names is < 0
rows_to_keep = (df[col_names] >= 0).sum(axis=1) == len(col_names)
print 'removing '+ str((~rows_to_keep).sum()) + ' rows...'
df = df[rows_to_keep]

(df[col_names] < 0).sum() # check if it worked
# Out:
# removing 13 rows...
# total_amount             0
# improvement_surcharge    0
# tip_amount               0
# mta_tax                  0
# extra                    0
# fare_amount              0
# dtype: int64

# %% [markdown]
# ### 3) Deleting "invalid" trips
# #### Inspecting trip distance

# %%
ax = df.loc[sample(df.index, 30000)].plot(y='trip_distance',kind='hist', bins=200)
ax.set_xlim([0,25]);

# %% [markdown]
# Delete trips that are longer than 50 miles...

# %%
rows_to_keep = df.trip_distance <= 50
print 'removing '+ str((~rows_to_keep).sum()) + ' rows...'
df = df[rows_to_keep]
# Out:
# removing 247 rows...

# %% [markdown]
# ...and shorter than 0.1 miles:

# %%
rows_to_keep = df.trip_distance >= 0.1
print 'removing '+ str((~rows_to_keep).sum()) + ' rows...'
df = df[rows_to_keep]
# Out:
# removing 30086 rows...

# %% [markdown]
# #### Inspecting trip fare

# %%
ax = df.loc[sample(df.index, 300000)].plot(y='fare_amount',kind='hist', bins=200)
ax.set_xlim([0,102]);

# %% [markdown]
# There seem to be a decent amount of trips with a fixed rate of 50 USD (see spike above).
#
# Now let's remove rows where the fare is below 1 USD:

# %%
rows_to_keep = df.fare_amount >= 1
print 'removing '+ str((~rows_to_keep).sum()) + ' rows...'
df = df[rows_to_keep]
# Out:
# removing 274 rows...

# %% [markdown]
# #### Inspecting trip duration

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df['trip_duration'] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime

# %%
df['trip_duration_minutes'] = df.trip_duration.dt.seconds/60

# %%
ax = df.loc[sample(df.index, 300000)].plot(y='trip_duration_minutes', kind='hist', bins=500)
ax.set_xlim([0,150]);

# %% [markdown]
# Remove trips that took less than half a minute...

# %%
rows_to_keep = df.trip_duration_minutes>0.5
print 'removing '+ str((~rows_to_keep).sum()) + ' rows...'
df = df[rows_to_keep]
# Out:
# removing 3625 rows...

# %% [markdown]
# ...as well as trips with a duration of more than 2 hours:

# %%
rows_to_keep = df.trip_duration_minutes<=2*60
print 'removing '+ str((~rows_to_keep).sum()) + ' rows...'
df = df[rows_to_keep]
# Out:
# removing 5988 rows...

# %% [markdown]
# #### Inspecting passenger count

# %%
df.plot(y='passenger_count', kind='hist', bins=30);

# %% [markdown]
# Remove trips with zero passenger count:

# %%
rows_to_keep = df.passenger_count > 0
print 'removing '+ str((~rows_to_keep).sum()) + ' rows...'
df = df[rows_to_keep]
# Out:
# removing 784 rows...

# %% [markdown]
# Remove trips with a passenger count of more than 6:

# %%
rows_to_keep = df.passenger_count <= 6
print 'removing '+ str((~rows_to_keep).sum()) + ' rows...'
df = df[rows_to_keep]
# Out:
# removing 17 rows...

# %% [markdown]
# #### Removing invalid location coordinates
# Remove trips that obviously did not start in NY:

# %%
within_NY = (df.pickup_latitude > 40) & (df.pickup_latitude < 40.9) & \
            (df.pickup_longitude > -74.4) & (df.pickup_longitude < -73.4)

print 'removing '+ str((~within_NY).sum()) + ' rows...'
df = df[within_NY]
# Out:
# removing 100456 rows...

# %% [markdown]
# Plot the pickup locations to check if they look good. Choose a random sample of all trips, since plotting all trips would take quite a while.

# %%
fig, ax = plt.subplots(figsize=(15, 10))
df.loc[sample(df.index, 200000)].plot(x='pickup_longitude', y='pickup_latitude', 
                                      kind='scatter', ax=ax, alpha=0.3, s=3)
ax.set_xlim([-74.2, -73.7])
ax.set_ylim([40.6, 40.9]);

# %% [markdown]
# The above plot looks reasonable, you can clearly identify the geometry of New York. Let's plot a small subset of data points on a map. Next to central NY, one can identify small hotspots at the surrounding airports.

# %%
subdf = df.loc[sample(df.index, 10000)] # subsample df 
data = subdf[['pickup_latitude', 'pickup_longitude']].values

mapa = folium.Map([40.7, -73.9], zoom_start=11, tiles='stamentoner') # create heatmap
mapa.add_children(plugins.HeatMap(data, min_opacity=0.005, max_zoom=18,
                                  max_val=0.01, radius=3, blur=3))
mapa
# Out:
#             <div style="width:100%;">
#             <div style="position:relative;width:100%;height:0;padding-bottom:60%;">
#             <iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;">
#             </iframe>
#             </div></div>

# %% [markdown]
# ### Inspecting the tip
# As the tip distribution below shows, people tend to tip whole numbers of dollars (see peaks at e.g. 1 and 2 dollars).

# %%
fig, ax = plt.subplots(figsize=(12,4))
ax = df.loc[sample(df.index, 100000)].plot(y='tip_amount', kind='hist',bins=1500, ax=ax)
ax.set_xlim([0,10.5])
ax.set_xticks(np.arange(0, 11, 0.5));

# %% [markdown]
# A useful metric for a taxi driver to compare tips is the percentage of tip given with respect to the total fare amount.

# %%
# check if the fares and fees sum up to total_amount
print pd.concat([df.tip_amount + df.fare_amount + df.tolls_amount + \
           df.extra + df.mta_tax  + df.improvement_surcharge, \
           df.total_amount], axis=1).head()

# calculate tip percentage
df['total_fare'] = df.total_amount - df.tip_amount
df['tip_percentage'] = df.tip_amount / df.total_fare * 100
# Out:
#        0  total_amount
# 1   8.30          8.30
# 2  11.00         11.00
# 3  17.16         17.16
# 5  10.55         10.55
# 6  16.30         16.30

# %% [markdown]
# The tip percentage distribution below shows that people mostly seem to tip 0, 20, 25 or 30%.

# %%
data = df.loc[sample(df.index, 100000)].tip_percentage.values
plt.hist(data, np.arange(min(data)-0.5, max(data)+1.5)) 
plt.gca().set_xlim([0,35])
plt.gca().set_xticks(np.arange(0, 51, 5));
plt.legend(['tip_percentage']);

# %% [markdown]
# Remove trips where a tip of more than 100% was recorded, regarding them as invalid outliers.

# %%
rows_to_keep = df.tip_percentage <= 100
print 'removing '+ str((~rows_to_keep).sum()) + ' rows...'
df = df[rows_to_keep]
# Out:
# removing 5015 rows...

# %%
df.tip_percentage.mean()
# Out:
# 18.455572081937966

# %%
df.tip_percentage.median()
# Out:
# 19.999999999999996

# %%
df.tip_percentage.mode()
# Out:
# 0    20
# dtype: float64

# %%
df.tip_percentage.quantile(0.25)
# Out:
# 15.384615384615385

# %%
# fig, ax = plt.subplots(figsize=(14,5))
# ax = df.loc[sample(df.index, 100000)].tip_percentage.plot(kind='hist',bins=2000, cumulative=True)
# ax.set_xlim([0,200])

# %% [markdown]
# Tip percentage by day of the week (Monday=0, Sunday=6). People tend to tip a little less on weekends (day 5-6).

# %%
df['pickup_weekday'] = df.tpep_pickup_datetime.dt.dayofweek
df['pickup_hour'] = df.tpep_pickup_datetime.dt.hour
ax = df.groupby('pickup_weekday').mean().plot(y='tip_percentage',kind='bar')
ax.set_ylim([18,19])
ax.set_title('average tip percentage')

# %%
# fig, ax = plt.subplots(figsize=(10,8))
# df.boxplot('tip_percentage', by='pickup_weekday', showmeans=True, ax=ax)

# %% [markdown]
# The average tip percentage also depends on the time. People tend to tip less during the night. On weekdays, the maximum tip is achieved between 9 am and 3 pm.

# %%
plt.subplots(figsize=(20, 10))
df['pickup_hour'] = df.tpep_pickup_datetime.dt.hour
for i in range(7):
    ax = plt.subplot(2, 4, i+1)
    df[df.pickup_weekday==i].groupby('pickup_hour').mean().plot(y='tip_percentage', kind='bar', ax=ax)
    ax.set_ylim([17,19.5])
    ax.set_title('day ' + str(i))

# %% [markdown]
# Same data again, plotted as lines in the same subplot:

# %%
fig, ax = plt.subplots(figsize=(12, 6))
for i in range(7):
    df[df.pickup_weekday==i].groupby('pickup_hour').mean().plot(y='tip_percentage', ax=ax)
plt.legend(['day ' + str(x) for x in range(7)])
ax.set_ylabel('average tip percentage')

# %% [markdown]
# Let's look at the number of trips per hour and day:

# %%
fig, ax = plt.subplots(figsize=(12, 6))
for i in range(7):
    df[df.pickup_weekday==i].groupby('pickup_hour').size().plot(ax=ax)
plt.legend(['day ' + str(x) for x in range(7)])
ax.set_ylabel('number of trips')

# %%
axs = df.loc[sample(df.index, 30000)].tip_percentage.hist(by=df.pickup_hour, bins=50, sharex=True, figsize=(16,16));
[ax.set_xlim([0,50]) for ax in axs.flatten()];

# %%
# create weekend feature
df['is_weekend'] = 0
df.loc[(df.pickup_weekday == 5) | (df.pickup_weekday == 6), 'is_weekend'] = 1

# %% [markdown]
# The tip percentage does seem to depend too much on the number of passengers:

# %%
fig, ax = plt.subplots(figsize=(8,7))
df.boxplot('tip_percentage', by='passenger_count', showmeans=True, ax=ax)
ax.set_ylim([15,21])
# Out:
# (15, 21)

# %% [markdown]
# # Create local clusters

# %% [markdown]
# ### MiniBatchKMeans

# %%
X = df[['pickup_longitude','pickup_latitude']]

mbk = MiniBatchKMeans(n_clusters=70, random_state=2, batch_size=1000, 
                      max_iter = 500, verbose=0).fit(X)
y_pred = mbk.predict(X)

# %%
df['cluster_id'] = y_pred

subidx = sample(X.index, 100000)

fig, ax = plt.subplots(figsize=(17, 12))
plt.scatter(df.loc[subidx, 'pickup_longitude'], df.loc[subidx, 'pickup_latitude'], c=df.loc[subidx,'cluster_id'], alpha=0.5, s=20, edgecolor='none')
plt.scatter(mbk.cluster_centers_[:,0], mbk.cluster_centers_[:,1], c=range(mbk.n_clusters), s=40)
ax.set_xlim([-74.2, -73.7])
ax.set_ylim([40.6, 40.9])
# Out:
# (40.6, 40.9)

# %%
fig, ax = plt.subplots(figsize=(12, 12))
plt.scatter(mbk.cluster_centers_[:,0], mbk.cluster_centers_[:,1], c=range(mbk.n_clusters), s=40)
mplleaflet.display(fig=ax.figure, tiles='cartodb_positron')
# Out:
# <iframe src="...

# %%
from scipy.spatial import Voronoi, voronoi_plot_2d
import shapely.geometry
import shapely.ops

points = np.hstack((mbk.cluster_centers_[:,0][:,np.newaxis], mbk.cluster_centers_[:,1][:,np.newaxis]))
vor = Voronoi(points)
ax = voronoi_plot_2d(vor)
mplleaflet.display(fig=ax.figure, tiles='cartodb_positron')
# Out:
# <iframe src="...

# %% [markdown]
# The following plot shows the mean of the tip percentage, and the lower quartile of the tip percentage, aggregated over the clusters:

# %%
subidx = sample(df.index, 100000)

cluster_means = df.groupby('cluster_id').tip_percentage.mean()
cluster_lowquartile = df.groupby('cluster_id').tip_percentage.quantile(0.25)

means = df.loc[subidx].join(cluster_means, on='cluster_id', rsuffix='_cluster_means').tip_percentage_cluster_means
df.loc[subidx].join(cluster_lowquartile , on='cluster_id', rsuffix='_cluster_lowquartile')
fig = plt.subplots(figsize=(20, 8))
ax = plt.subplot(1,2,1)
plt.scatter(df.loc[subidx, 'pickup_longitude'], df.loc[subidx, 'pickup_latitude'], c=means, alpha=0.7, s=10, edgecolor='none')
ax.set_xlim([-74.2, -73.7])
ax.set_ylim([40.6, 40.9])
plt.colorbar()
plt.title('average tip percentage')

lowquartile = df.loc[subidx].join(cluster_lowquartile , on='cluster_id', rsuffix='_cluster_lowquartile').tip_percentage_cluster_lowquartile
ax = plt.subplot(1,2,2)
plt.scatter(df.loc[subidx, 'pickup_longitude'], df.loc[subidx, 'pickup_latitude'], c=lowquartile , alpha=0.7, s=10, edgecolor='none')
ax.set_xlim([-74.2, -73.7])
ax.set_ylim([40.6, 40.9])
plt.colorbar()
plt.title('lower 25% quantile of tip percentage')

# %% [markdown]
# The same plot as above, but this time showing only data from Monday to Thursday, between 7 and 10 am (when I suppose people are mostly commuting to work.

# %%
monday_to_thursday = df.pickup_weekday <= 4
morning = (df.pickup_hour >= 6) & (df.pickup_hour <= 10)

subidx = sample(df[monday_to_thursday & morning].index, 100000)

cluster_means = df[monday_to_thursday & morning].groupby('cluster_id').tip_percentage.mean()
cluster_lowquartile = df[monday_to_thursday & morning].groupby('cluster_id').tip_percentage.quantile(0.25)

means = df.loc[subidx].join(cluster_means, on='cluster_id', rsuffix='_cluster_means').tip_percentage_cluster_means
df.loc[subidx].join(cluster_lowquartile , on='cluster_id', rsuffix='_cluster_lowquartile')
fig = plt.subplots(figsize=(20, 8))
ax = plt.subplot(1,2,1)
plt.scatter(df.loc[subidx, 'pickup_longitude'], df.loc[subidx, 'pickup_latitude'], c=means, alpha=0.7, s=10, edgecolor='none')
ax.set_xlim([-74.2, -73.7])
ax.set_ylim([40.6, 40.9])
plt.colorbar()
plt.title('average tip percentage')

lowquartile = df.loc[subidx].join(cluster_lowquartile , on='cluster_id', rsuffix='_cluster_lowquartile').tip_percentage_cluster_lowquartile
ax = plt.subplot(1,2,2)
plt.scatter(df.loc[subidx, 'pickup_longitude'], df.loc[subidx, 'pickup_latitude'], c=lowquartile , alpha=0.7, s=10, edgecolor='none')
ax.set_xlim([-74.2, -73.7])
ax.set_ylim([40.6, 40.9])
plt.colorbar()
plt.title('lower 25% quantile of tip percentage')

# %% [markdown]
# The same plot as above from Monday to Thursday, but this time between 9 and 11 pm.

# %%
monday_to_thursday = df.pickup_weekday <= 4
evening = (df.pickup_hour >= 21) & (df.pickup_hour <= 23)

subidx = sample(df[monday_to_thursday & evening].index, 100000)

cluster_means = df[monday_to_thursday & evening].groupby('cluster_id').tip_percentage.mean()
cluster_lowquartile = df[monday_to_thursday & evening].groupby('cluster_id').tip_percentage.quantile(0.25)

means = df.loc[subidx].join(cluster_means, on='cluster_id', rsuffix='_cluster_means').tip_percentage_cluster_means
df.loc[subidx].join(cluster_lowquartile , on='cluster_id', rsuffix='_cluster_lowquartile')
fig = plt.subplots(figsize=(20, 8))
ax = plt.subplot(1,2,1)
plt.scatter(df.loc[subidx, 'pickup_longitude'], df.loc[subidx, 'pickup_latitude'], c=means, alpha=0.7, s=10, edgecolor='none')
ax.set_xlim([-74.2, -73.7])
ax.set_ylim([40.6, 40.9])
plt.colorbar()
plt.title('average tip percentage')

lowquartile = df.loc[subidx].join(cluster_lowquartile , on='cluster_id', rsuffix='_cluster_lowquartile').tip_percentage_cluster_lowquartile
ax = plt.subplot(1,2,2)
plt.scatter(df.loc[subidx, 'pickup_longitude'], df.loc[subidx, 'pickup_latitude'], c=lowquartile , alpha=0.7, s=10, edgecolor='none')
ax.set_xlim([-74.2, -73.7])
ax.set_ylim([40.6, 40.9])
plt.colorbar()
plt.title('lower 25% quantile of tip percentage')

# %% [markdown]
# The same plot as above, but this time showing only data for saturday night, when people start to go out.

# %%
saturday = df.pickup_weekday == 5 
night = (df.pickup_hour >= 19) & (df.pickup_hour <= 23)

subidx = sample(df[saturday & night].index, 100000)

cluster_means = df[saturday & night].groupby('cluster_id').tip_percentage.mean()
cluster_lowquartile = df[saturday & night].groupby('cluster_id').tip_percentage.quantile(0.25)

means = df.loc[subidx].join(cluster_means, on='cluster_id', rsuffix='_cluster_means').tip_percentage_cluster_means
df.loc[subidx].join(cluster_lowquartile , on='cluster_id', rsuffix='_cluster_lowquartile')
fig = plt.subplots(figsize=(20, 8))
ax = plt.subplot(1,2,1)
plt.scatter(df.loc[subidx, 'pickup_longitude'], df.loc[subidx, 'pickup_latitude'], c=means, alpha=0.7, s=10, edgecolor='none')
ax.set_xlim([-74.2, -73.7])
ax.set_ylim([40.6, 40.9])
plt.colorbar()
plt.title('average tip percentage')

lowquartile = df.loc[subidx].join(cluster_lowquartile , on='cluster_id', rsuffix='_cluster_lowquartile').tip_percentage_cluster_lowquartile
ax = plt.subplot(1,2,2)
plt.scatter(df.loc[subidx, 'pickup_longitude'], df.loc[subidx, 'pickup_latitude'], c=lowquartile , alpha=0.7, s=10, edgecolor='none')
ax.set_xlim([-74.2, -73.7])
ax.set_ylim([40.6, 40.9])
plt.colorbar()
plt.title('lower 25% quantile of tip percentage')

# %% [markdown]
# Show the Monday to Thursday morning plot for the average tip percentage from above on a map:|

# %%
cluster_means = df[monday_to_thursday & morning].groupby('cluster_id').tip_percentage.mean()

fig, ax = plt.subplots(figsize=(12, 12))
plt.scatter(mbk.cluster_centers_[:,0], mbk.cluster_centers_[:,1], c=cluster_means, s=40)
mplleaflet.display(fig=ax.figure, tiles='cartodb_positron')
# Out:
# <iframe src="...

# %% [markdown]
# Check if the mean tip percentage values in the clusters change depending on the day.
# The trend of all clusters is quite similar, some differences are evident for the weekends and Friday.

# %%
fig, ax = plt.subplots(figsize=(20, 12))
for i in range(7):
    df[df.pickup_weekday==i].groupby('cluster_id').tip_percentage.mean().plot(y='tip_percentage', ax=ax)
plt.legend(['day ' + str(x) for x in range(7)])

# %% [markdown]
# Check if the mean tip percentage values in the clusters change depending on time of the day. Let's start with Monday-Thursday:

# %%
# cut hour in 3 hour intervals
bins = [0,8,11,16,20,24]
df['pickup_time_categories'] = pd.cut(df['pickup_hour'], bins, include_lowest=True)

# %%
fig, ax = plt.subplots(figsize=(20, 12))
monday_to_thursday = df.pickup_weekday <= 4
for time_category in df['pickup_time_categories'].unique():
    subdf = df[monday_to_thursday  & (df.pickup_time_categories==time_category)]
    subdf.groupby('cluster_id').tip_percentage.mean().plot(y='tip_percentage', ax=ax)
plt.legend(df['pickup_time_categories'].unique())

# %%
# how many samples in the clusters
df.groupby('cluster_id').size().sort_values().head(10)
# Out:
# cluster_id
# 33     2042
# 56     2069
# 34     4632
# 47     6502
# 22     7352
# 51     9098
# 30    10116
# 69    14237
# 21    17920
# 40    20533
# dtype: int64

# %% [markdown]
# # try some ML

# %%
from sklearn.cross_validation import KFold, train_test_split, cross_val_score, cross_val_predict
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.metrics import confusion_matrix, mean_squared_error, r2_score, mean_absolute_error
import models

# %%
X_train, X_test, y_train, y_test = train_test_split(df[features],\
                                            df.tip, \
                                                    test_size = 0.2, random_state=5)

# %%
model = RandomForestRegressor(verbose=2, estimators=10, max_depth=None, min_samples_split=10, random_state=0,max_features='auto')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2569c44faf66> in <module>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
subidx = sample(X_train.index,1000000)
subdf = X_train.loc[subidx]

features = ['pickup_hour', 'pickup_weekday', 'pickup_latitude', 'pickup_longitude','passenger_count', 'trip_distance', 'RateCodeID', '']
model.fit(subdf[features],y_train[subidx])

# %%
subidx_test = sample(X_test[features].index,200000)
test_predicted = model.predict(X_test[features].loc[subidx_test])
train_predicted  = model.predict(X_train[features].loc[subidx])
print("MAE test/train: %.1f/%.1f" % (mean_absolute_error(y_test.loc[subidx_test], test_predicted),mean_absolute_error(y_train.loc[subidx], train_predicted)))
# Out:
# [Parallel(n_jobs=4)]: Done  33 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    6.1s finished
# [Parallel(n_jobs=4)]: Done  33 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    6.3s finished
# MAE test/train: 4.9/3.4

# %%
models.PlotGBRIterations(model, X_test[features].loc[subidx_test], y_test.loc[subidx_test])

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
models.PlotFeatureImportance(model, features)
plt.subplot(1,2,2)
plt.plot(y_test.loc[subidx_test], test_predicted, 'x')
plt.plot(y_train[subidx],y_train[subidx],'-r')

# %% [markdown]
# ### Try ML only on say Monday mornings

# %%
features = ['pickup_latitude', 'pickup_longitude']
target = 'tip_percentage'
morning = (df.pickup_hour >= 7) & (df.pickup_hour <= 9)
subdf = df[(df.pickup_weekday < 3) & morning]
print subdf.shape
X_train, X_test, y_train, y_test = train_test_split(subdf[features],\
                                            subdf[target], \
                                                    test_size = 0.3, random_state=5)
# Out:
# (585514, 23)

# %%
model = RandomForestRegressor(verbose=0, n_estimators=25, random_state=0, max_features='auto', n_jobs=4, min_samples_leaf=400)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None, min_samples_leaf=400,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=25, n_jobs=4, oob_score=False, random_state=0,
#            verbose=0, warm_start=False)

# %%
test_predicted = model.predict(X_test)
train_predicted  = model.predict(X_train)

print("MAE median test/train: %.2f/%.2f" % (mean_absolute_error( y_train.median()*np.ones(test_predicted.shape), y_test),mean_absolute_error(y_train.median()*np.ones(train_predicted.shape), y_train)))
print("MSE median test/train: %.2f/%.2f" % (mean_squared_error(y_train.median()*np.ones(test_predicted.shape), y_test),mean_squared_error(y_train.median()*np.ones(train_predicted.shape), y_train)))
print("MSE mean test/train: %.2f/%.2f" % (mean_squared_error(y_train.mean()*np.ones(test_predicted.shape), y_test),mean_squared_error(y_train.mean()*np.ones(train_predicted.shape), y_train)))

print("MSE random forest test/train: %.2f/%.2f" % (mean_squared_error(y_test, test_predicted),mean_squared_error(y_train, train_predicted)))
print("MAE random forest test/train: %.2f/%.2f" % (mean_absolute_error(y_test, test_predicted),mean_absolute_error(y_train, train_predicted)))
# Out:
# MAE median test/train: 4.17/4.14
# MSE median test/train: 46.51/46.18
# MSE mean test/train: 44.14/43.84
# MSE random forest test/train: 43.28/42.54
# MAE random forest test/train: 4.59/4.55

# %%
fig, ax = plt.subplots(figsize=(20, 20))
plt.scatter(X_train['pickup_longitude'], X_train['pickup_latitude'], c=train_predicted , alpha=0.7, s=10, edgecolor='none')
ax.set_xlim([-74.2, -73.7])
ax.set_ylim([40.6, 40.9])
plt.colorbar();

# %%
plt.figure(figsize=(15,15))
plt.plot(test_predicted,-test_predicted + y_test, 'x', alpha=0.1, markersize=5)
plt.plot([14,22],[0,0],'r-');

# %%
# df = pd.read_pickle('df.pickle')

# %%
df.to_pickle('df.pickle')

# %%
X[ind[0],0]
# Out:
# array([ 0.4236548 ,  0.5488135 ,  0.43758721,  0.60276338,  0.56804456,
#         0.77815675])

# %%
from sklearn.neighbors import KDTree
np.random.seed(0)
X = np.random.random((10, 2))  # 10 points in 2 dimensions
print X
tree = KDTree(X, leaf_size=2)     

ind = tree.query_radius(X[0], r=0.2)[0]
print ind  # indices of neighbors within distance 0.3
plt.figure(figsize=(10,10))
plt.scatter(X[:,0],X[:,1])
plt.plot(X[0,0],X[0,1],'xr', markersize=15)
plt.plot(X[ind,0],X[ind,1],'+g', markersize=15)
# Out:
# [[ 0.5488135   0.71518937]
#  [ 0.60276338  0.54488318]
#  [ 0.4236548   0.64589411]
#  [ 0.43758721  0.891773  ]
#  [ 0.96366276  0.38344152]
#  [ 0.79172504  0.52889492]
#  [ 0.56804456  0.92559664]
#  [ 0.07103606  0.0871293 ]
#  [ 0.0202184   0.83261985]
#  [ 0.77815675  0.87001215]]
# [2 0 1]
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
